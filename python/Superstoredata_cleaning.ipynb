# %%
import pandas as pd
#Load datasets
df = pd.read_csv('SampleSuperstore.csv')

# %%
df.head(100)
# Out:
#          Ship Mode      Segment        Country             City       State  \
# 0     Second Class     Consumer  United States        Henderson    Kentucky
# 1     Second Class     Consumer  United States        Henderson    Kentucky
# 2     Second Class    Corporate  United States      Los Angeles  California
# 3   Standard Class     Consumer  United States  Fort Lauderdale     Florida
# 4   Standard Class     Consumer  United States  Fort Lauderdale     Florida
# ..             ...          ...            ...              ...         ...
# 95  Standard Class  Home Office  United States         Portland      Oregon
# 96    Second Class  Home Office  United States    New York City    New York
# 97     First Class     Consumer  United States    San Francisco  California
# 98  Standard Class    Corporate  United States       Saint Paul   Minnesota
# 99  Standard Class  Home Office  United States          Chicago    Illinois
#
# ...

# %%
#Checking for dirt in the data
print("Check for missing values before clenaing:")
print(df.isnull().sum())
# Out:
# Check for missing values before clenaing:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#The report shows there are no missing values.
